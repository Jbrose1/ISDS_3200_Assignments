# %% [markdown]
# ## Assignment 4 - 911 Call Analysis
#
# Use Python to answer the following questions about the data.

# %% [markdown]
# #### 1. Import required Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
#  #### 2. Read 911.csv provided to you on Moodle as a data frame

# %%
ds = pd.read_csv('911.csv')

# %% [markdown]
# #### 3. Display first 10 records of this data set

# %%
ds.head(10)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# 5  40.253473 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
# 6  40.182111 -75.127795  LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...
# 7  40.217286 -75.405182  COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...
# 8  40.289027 -75.399590  MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...
# 9  40.102398 -75.291458  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...
#
#        zip                        title            timeStamp  \
# 0  19525.0       EMS: BACK PAINS/INJURY  2015-12-10 17:10:52
# 1  19446.0      EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21
# 2  19401.0          Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21
# 3  19401.0       EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36
# 4      NaN               EMS: DIZZINESS  2015-12-10 16:56:52
# 5  19446.0             EMS: HEAD INJURY  2015-12-10 15:39:04
# 6  19044.0         EMS: NAUSEA/VOMITING  2015-12-10 16:46:48
# 7  19426.0   EMS: RESPIRATORY EMERGENCY  2015-12-10 16:17:05
# 8  19438.0        EMS: SYNCOPAL EPISODE  2015-12-10 16:51:42
# 9  19462.0  Traffic: VEHICLE ACCIDENT -  2015-12-10 17:35:41
#
#                  twp                                      addr  e
# 0        NEW HANOVER                    REINDEER CT & DEAD END  1
# 1  HATFIELD TOWNSHIP                BRIAR PATH & WHITEMARSH LN  1
# 2         NORRISTOWN                                  HAWS AVE  1
# 3         NORRISTOWN                        AIRY ST & SWEDE ST  1
# 4   LOWER POTTSGROVE                  CHERRYWOOD CT & DEAD END  1
# 5           LANSDALE                     CANNON AVE & W 9TH ST  1
# 6            HORSHAM                  LAUREL AVE & OAKDALE AVE  1
# 7           SKIPPACK              COLLEGEVILLE RD & LYWISKI RD  1
# 8      LOWER SALFORD             MAIN ST & OLD SUMNEYTOWN PIKE  1
# 9           PLYMOUTH  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD  1

# %% [markdown]
# #### 4. How many records does the file contain?  (you may use a property of the dataframe that will show this inormation)

# %%
len(ds)
# Out:
# 423909

# %% [markdown]
# #### 5. What are the top 10 towns with most 911 calls? (twp column)

# %%
ds['twp'].value_counts()[:10]
# Out:
# LOWER MERION        36441
# ABINGTON            25835
# NORRISTOWN          23883
# UPPER MERION        22694
# CHELTENHAM          19629
# POTTSTOWN           17500
# UPPER MORELAND      14707
# LOWER PROVIDENCE    14025
# PLYMOUTH            12800
# UPPER DUBLIN        11910
# Name: twp, dtype: int64

# %% [markdown]
# #### 6. What are the top 10 zipcodes with most 911 calls?

# %%
zip_count = ds['zip'].value_counts()
zip_count.head(10)
# Out:
# 19401.0    28656
# 19464.0    27948
# 19403.0    21631
# 19446.0    20496
# 19406.0    14097
# 19002.0    13380
# 19468.0    12393
# 19046.0    11720
# 19454.0    11457
# 19090.0    11149
# Name: zip, dtype: int64

# %% [markdown]
# ## Creating new features

# %% [markdown]
# #### 7. Create a new column called "CallType". Content of this new column is derived from the title column. Each title is prefixed with the call type.
#
# ##### For example, if the title column value is EMS: BACK PAINS/INJURY , the call type column value would be EMS. **

# %%
ds['CallType'] = ds['title'].apply(lambda title: title.split(':')[0])

ds
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 423904  BUCK RD & WOODWARD DR; LOWER MORELAND; 2018-11...  19006.0
# 423905  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423906  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR; LOWER GWYNEDD...  19002.0
# 423908   HOFFMAN  ; LOWER GWYNEDD; 2018-11-16 @ 08:46:25;  19422.0
#
#                               title            timeStamp                twp  \
# 0            EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1           EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2               Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3            EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4                    EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
# ...                             ...                  ...                ...
# 423904  Traffic: VEHICLE ACCIDENT -  2018-11-16 08:54:08     LOWER MORELAND
# 423905  Traffic: VEHICLE ACCIDENT -  2018-11-16 08:53:32      LOWER SALFORD
# 423906  Traffic: VEHICLE ACCIDENT -  2018-11-16 08:54:19      LOWER SALFORD
# 423907  Traffic: VEHICLE ACCIDENT -  2018-11-16 08:51:48      LOWER GWYNEDD
# 423908  Traffic: DISABLED VEHICLE -  2018-11-16 08:46:25      LOWER GWYNEDD
#
#                                    addr  e CallType
# 0                REINDEER CT & DEAD END  1      EMS
# 1            BRIAR PATH & WHITEMARSH LN  1      EMS
# 2                              HAWS AVE  1     Fire
# 3                    AIRY ST & SWEDE ST  1      EMS
# 4              CHERRYWOOD CT & DEAD END  1      EMS
# ...                                 ... ..      ...
# 423904            BUCK RD & WOODWARD DR  1  Traffic
# 423905                OAK DR & MOYER RD  1  Traffic
# 423906                OAK DR & MOYER RD  1  Traffic
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR  1  Traffic
# 423908                          HOFFMAN  1  Traffic
#
# [423909 rows x 10 columns]

# %% [markdown]
# #### 8. What is the number of calls for each call type. (How many calls per each call type)

# %%
ds['CallType'].value_counts()
# Out:
# EMS        208676
# Traffic    151458
# Fire        63775
# Name: CallType, dtype: int64

# %% [markdown]
# #### 9. Create a countplot of CallType

# %%
sns.countplot(x='CallType', data=ds)
# Out:
# <AxesSubplot:xlabel='CallType', ylabel='count'>

# %% [markdown]
# #### 10. use pandas to_datetime to convert the timestamp column from string data type to timestamp

# %%
ds['timeStamp'] = pd.to_datetime(ds['timeStamp'])
time = ds['timeStamp'].iloc[0]
ds
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 423904  BUCK RD & WOODWARD DR; LOWER MORELAND; 2018-11...  19006.0
# 423905  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423906  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR; LOWER GWYNEDD...  19002.0
# 423908   HOFFMAN  ; LOWER GWYNEDD; 2018-11-16 @ 08:46:25;  19422.0
#
#                               title           timeStamp                twp  \
# 0            EMS: BACK PAINS/INJURY 2015-12-10 17:10:52        NEW HANOVER
# 1           EMS: DIABETIC EMERGENCY 2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2               Fire: GAS-ODOR/LEAK 2015-12-10 14:39:21         NORRISTOWN
# 3            EMS: CARDIAC EMERGENCY 2015-12-10 16:47:36         NORRISTOWN
# 4                    EMS: DIZZINESS 2015-12-10 16:56:52   LOWER POTTSGROVE
# ...                             ...                 ...                ...
# 423904  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:08     LOWER MORELAND
# 423905  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:53:32      LOWER SALFORD
# 423906  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:19      LOWER SALFORD
# 423907  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:51:48      LOWER GWYNEDD
# 423908  Traffic: DISABLED VEHICLE - 2018-11-16 08:46:25      LOWER GWYNEDD
#
#                                    addr  e CallType
# 0                REINDEER CT & DEAD END  1      EMS
# 1            BRIAR PATH & WHITEMARSH LN  1      EMS
# 2                              HAWS AVE  1     Fire
# 3                    AIRY ST & SWEDE ST  1      EMS
# 4              CHERRYWOOD CT & DEAD END  1      EMS
# ...                                 ... ..      ...
# 423904            BUCK RD & WOODWARD DR  1  Traffic
# 423905                OAK DR & MOYER RD  1  Traffic
# 423906                OAK DR & MOYER RD  1  Traffic
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR  1  Traffic
# 423908                          HOFFMAN  1  Traffic
#
# [423909 rows x 10 columns]

# %% [markdown]
# #### 11. Create new columns to represent "Hour" from the timeStamp column. Now that you converted the data type of that column to timestamp, you can access hour by using df['timeStamp'].iloc[0].hour
#
# you can use apply and lambda function to extract this information from the timeStamp column and create the new columns

# %%
ds['Hour'] = ds['timeStamp'].apply(lambda time: time.hour)
ds
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 423904  BUCK RD & WOODWARD DR; LOWER MORELAND; 2018-11...  19006.0
# 423905  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423906  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR; LOWER GWYNEDD...  19002.0
# 423908   HOFFMAN  ; LOWER GWYNEDD; 2018-11-16 @ 08:46:25;  19422.0
#
#                               title           timeStamp                twp  \
# 0            EMS: BACK PAINS/INJURY 2015-12-10 17:10:52        NEW HANOVER
# 1           EMS: DIABETIC EMERGENCY 2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2               Fire: GAS-ODOR/LEAK 2015-12-10 14:39:21         NORRISTOWN
# 3            EMS: CARDIAC EMERGENCY 2015-12-10 16:47:36         NORRISTOWN
# 4                    EMS: DIZZINESS 2015-12-10 16:56:52   LOWER POTTSGROVE
# ...                             ...                 ...                ...
# 423904  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:08     LOWER MORELAND
# 423905  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:53:32      LOWER SALFORD
# 423906  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:19      LOWER SALFORD
# 423907  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:51:48      LOWER GWYNEDD
# 423908  Traffic: DISABLED VEHICLE - 2018-11-16 08:46:25      LOWER GWYNEDD
#
#                                    addr  e CallType  Hour
# 0                REINDEER CT & DEAD END  1      EMS    17
# 1            BRIAR PATH & WHITEMARSH LN  1      EMS    17
# 2                              HAWS AVE  1     Fire    14
# 3                    AIRY ST & SWEDE ST  1      EMS    16
# 4              CHERRYWOOD CT & DEAD END  1      EMS    16
# ...                                 ... ..      ...   ...
# 423904            BUCK RD & WOODWARD DR  1  Traffic     8
# 423905                OAK DR & MOYER RD  1  Traffic     8
# 423906                OAK DR & MOYER RD  1  Traffic     8
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR  1  Traffic     8
# 423908                          HOFFMAN  1  Traffic     8
#
# [423909 rows x 11 columns]

# %% [markdown]
# #### 12. Create new columns to represent "Month" from the timeStamp column. Now that you converted the data type of that column to timestamp, you can access month by using df['timeStamp'].iloc[0].Month

# %%
ds['Month'] = ds['timeStamp'].apply(lambda time: time.month)
ds
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 423904  BUCK RD & WOODWARD DR; LOWER MORELAND; 2018-11...  19006.0
# 423905  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423906  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR; LOWER GWYNEDD...  19002.0
# 423908   HOFFMAN  ; LOWER GWYNEDD; 2018-11-16 @ 08:46:25;  19422.0
#
#                               title           timeStamp                twp  \
# 0            EMS: BACK PAINS/INJURY 2015-12-10 17:10:52        NEW HANOVER
# 1           EMS: DIABETIC EMERGENCY 2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2               Fire: GAS-ODOR/LEAK 2015-12-10 14:39:21         NORRISTOWN
# 3            EMS: CARDIAC EMERGENCY 2015-12-10 16:47:36         NORRISTOWN
# 4                    EMS: DIZZINESS 2015-12-10 16:56:52   LOWER POTTSGROVE
# ...                             ...                 ...                ...
# 423904  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:08     LOWER MORELAND
# 423905  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:53:32      LOWER SALFORD
# 423906  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:19      LOWER SALFORD
# 423907  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:51:48      LOWER GWYNEDD
# 423908  Traffic: DISABLED VEHICLE - 2018-11-16 08:46:25      LOWER GWYNEDD
#
#                                    addr  e CallType  Hour  Month
# 0                REINDEER CT & DEAD END  1      EMS    17     12
# 1            BRIAR PATH & WHITEMARSH LN  1      EMS    17     12
# 2                              HAWS AVE  1     Fire    14     12
# 3                    AIRY ST & SWEDE ST  1      EMS    16     12
# 4              CHERRYWOOD CT & DEAD END  1      EMS    16     12
# ...                                 ... ..      ...   ...    ...
# 423904            BUCK RD & WOODWARD DR  1  Traffic     8     11
# 423905                OAK DR & MOYER RD  1  Traffic     8     11
# 423906                OAK DR & MOYER RD  1  Traffic     8     11
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR  1  Traffic     8     11
# 423908                          HOFFMAN  1  Traffic     8     11
#
# [423909 rows x 12 columns]

# %% [markdown]
# #### 13. Create new columns to represent "Day of Week" from the timeStamp column. Now that you converted the data type of that column to timestamp, you can access day of week by using df['timeStamp'].iloc[0].dayofweek
#
# Note that the Day of Week will be an integer 0-6 with 0 represnting Monday

# %%
ds['Day of week'] = ds['timeStamp'].apply(lambda time: time.dayofweek)
ds
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 423904  BUCK RD & WOODWARD DR; LOWER MORELAND; 2018-11...  19006.0
# 423905  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423906  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR; LOWER GWYNEDD...  19002.0
# 423908   HOFFMAN  ; LOWER GWYNEDD; 2018-11-16 @ 08:46:25;  19422.0
#
#                               title           timeStamp                twp  \
# 0            EMS: BACK PAINS/INJURY 2015-12-10 17:10:52        NEW HANOVER
# 1           EMS: DIABETIC EMERGENCY 2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2               Fire: GAS-ODOR/LEAK 2015-12-10 14:39:21         NORRISTOWN
# 3            EMS: CARDIAC EMERGENCY 2015-12-10 16:47:36         NORRISTOWN
# 4                    EMS: DIZZINESS 2015-12-10 16:56:52   LOWER POTTSGROVE
# ...                             ...                 ...                ...
# 423904  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:08     LOWER MORELAND
# 423905  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:53:32      LOWER SALFORD
# 423906  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:19      LOWER SALFORD
# 423907  Traffic: VEHICLE ACCIDENT - 2018-11-16 08:51:48      LOWER GWYNEDD
# 423908  Traffic: DISABLED VEHICLE - 2018-11-16 08:46:25      LOWER GWYNEDD
#
#                                    addr  e CallType  Hour  Month  Day of week
# 0                REINDEER CT & DEAD END  1      EMS    17     12            3
# 1            BRIAR PATH & WHITEMARSH LN  1      EMS    17     12            3
# 2                              HAWS AVE  1     Fire    14     12            3
# 3                    AIRY ST & SWEDE ST  1      EMS    16     12            3
# 4              CHERRYWOOD CT & DEAD END  1      EMS    16     12            3
# ...                                 ... ..      ...   ...    ...          ...
# 423904            BUCK RD & WOODWARD DR  1  Traffic     8     11            4
# 423905                OAK DR & MOYER RD  1  Traffic     8     11            4
# 423906                OAK DR & MOYER RD  1  Traffic     8     11            4
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR  1  Traffic     8     11            4
# 423908                          HOFFMAN  1  Traffic     8     11            4
#
# [423909 rows x 13 columns]

# %% [markdown]
# #### 14. use seaborn to create a count plot for "Day of Week" column categorized by the callType.

# %%
sns.countplot(x='Day of week', data=ds, hue='CallType')
# Out:
# <AxesSubplot:xlabel='Day of week', ylabel='count'>

# %% [markdown]
# #### 15. use seaborn to create a count plot for "Month" column categorized by the callType.

# %%
sns.countplot(x='Month', data=ds, hue='CallType')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %% [markdown]
# #### 16. Create a plot that shows number of calls per month

# %%
ds['Month'].value_counts().plot(kind='bar')
plt.ylabel('Calls')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# #### 17. Create a plot that displays the number of calls per month for EMS call type

# %%
EMS=ds[ds.CallType.isin(["EMS"])]
pvt3=pd.pivot_table(EMS,columns="Month",values="CallType",aggfunc=len,fill_value=0)
pvt3["Total"]=round(pvt3.sum(numeric_only=True, axis=1),2)
df3=pvt3.sort_values(by="Total", ascending=False).head(5)
eg=df3.drop("Total",axis=1).transpose()
eg.plot(grid=True)
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# #### 18. Create a plot that displays the number of calls per month for Traffic call type

# %%
Traffic=ds[ds.CallType.isin(["Traffic"])]
pvt4=pd.pivot_table(Traffic,columns="Month",values='CallType',aggfunc=len,fill_value=0)
pvt4["Total"]=round(pvt4.sum(numeric_only=True, axis=1),2)
df4=pvt4.sort_values(by="Total", ascending=False).head(5)
eg0=df3.drop("Total",axis=1).transpose()
eg0.plot(grid=True)
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# #### 19. Display plot from questions 17 and 18 next to each other. (1 row, 2 columns)

# %%
fig0,axes4 = plt.subplots(nrows=1,ncols=2, figsize=(8,8))

axes4[0].plot(eg)
axes4[0].grid(True)
axes4[1].plot(eg0)
axes4[1].grid(True)
