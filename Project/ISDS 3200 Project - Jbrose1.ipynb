# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Cyber Security Breaches.csv')

# %%
df.set_index('Number')
# Out:
#                                    Name_of_Covered_Entity State  \
# Number
# 0                              Brooke Army Medical Center    TX
# 1               Mid America Kidney Stone Association, LLC    MO
# 2         Alaska Department of Health and Social Services    AK
# 3       Health Services for Children with Special Need...    DC
# 4                                L. Douglas Carlson, M.D.    CA
# ...                                                   ...   ...
# 1050                        Puerto Rico Health Insurance     PR
# 1051                         Hospitalists of Brandon, LLC    FL
# 1052                        Santa Rosa Memorial Hospital     CA
# 1053           Group Health Plan of Hurley Medical Center    MI
# 1054                              Abrham Tekola, M.D.,INC    CA
#
#                 Business_Associate_Involved  Individuals_Affected  \
# Number
# 0                                       NaN                  1000
# ...

# %%
sum1 = df['Number']

# %%
null_values = df.isnull().sum()
null_values
# Out:
# Number                                0
# Name_of_Covered_Entity                0
# State                                 0
# Business_Associate_Involved         784
# Individuals_Affected                  0
# Date_of_Breach                        0
# Type_of_Breach                        0
# Location_of_Breached_Information      0
# Date_Posted_or_Updated                0
# Summary                             913
# breach_start                          0
# breach_end                          910
# year                                  0
# dtype: int64

# %%
sns.countplot(x=null_values, data=df)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
#Dropping unecessary columns
df.drop('Summary', axis=1,inplace=True)
df.drop('breach_end', axis=1, inplace=True)
df.drop('Business_Associate_Involved', axis=1, inplace=True)
df.drop('Date_Posted_or_Updated', axis=1, inplace=True)
df
# Out:
#       Number                             Name_of_Covered_Entity State  \
# 0          0                         Brooke Army Medical Center    TX
# 1          1          Mid America Kidney Stone Association, LLC    MO
# 2          2    Alaska Department of Health and Social Services    AK
# 3          3  Health Services for Children with Special Need...    DC
# 4          4                           L. Douglas Carlson, M.D.    CA
# ...      ...                                                ...   ...
# 1050    1050                      Puerto Rico Health Insurance     PR
# 1051    1051                       Hospitalists of Brandon, LLC    FL
# 1052    1052                      Santa Rosa Memorial Hospital     CA
# 1053    1053         Group Health Plan of Hurley Medical Center    MI
# 1054    1054                            Abrham Tekola, M.D.,INC    CA
#
#       Individuals_Affected Date_of_Breach                  Type_of_Breach  \
# ...

# %%
#Displaying the dataframes information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Number                            1055 non-null   int64
#  1   Name_of_Covered_Entity            1055 non-null   object
#  2   State                             1055 non-null   object
#  3   Individuals_Affected              1055 non-null   int64
#  4   Date_of_Breach                    1055 non-null   object
#  5   Type_of_Breach                    1055 non-null   object
#  6   Location_of_Breached_Information  1055 non-null   object
#  7   breach_start                      1055 non-null   object
#  8   year                              1055 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 74.3+ KB

# %%
#converting breach_start to a datetime object so that I can run certain functions off of it.
df['breach_start'] = pd.to_datetime(df['breach_start'])

# %%
#Question 1: What is the first date stated in the dataset?
earliest = df['breach_start'].min()
earliest
# Out:
# Timestamp('1997-01-01 00:00:00')

# %%
#Question 2: What is the last date in the dataset?
latest = df['breach_start'].max()
latest
# Out:
# Timestamp('2014-06-02 00:00:00')

# %%
#Question 3: How many individuals in total were affected by data breaches?
affected = df['Individuals_Affected'].sum()
affected
# Out:
# 31926430

# %%
#Question 4: How many years does this dataset cover?
date_range = latest - earliest
date_range
# Out:
# Timedelta('6361 days 00:00:00')

# %%
#Question 4 (CONT')
date_range_years = 6361 / 365
date_range_years
# Out:
# 17.427397260273974

# %%
#Question 5: How many unique states were affected by (a) data breach(es)[This dataset also includes D.C. and Puerto Rico]?
affected_states = df['State'].unique()
len(affected_states)
# Out:
# 52

# %%
#Question 6: How many of each breach type exist in the dataset?
breach_types = df['Type_of_Breach'].value_counts()
breach_types
# Out:
# Theft                                                         516
# Unauthorized Access/Disclosure                                148
# Other                                                          91
# Loss                                                           85
# Hacking/IT Incident                                            75
# Improper Disposal                                              38
# Theft, Unauthorized Access/Disclosure                          26
# Theft, Loss                                                    15
# Unknown                                                        10
# Unauthorized Access/Disclosure, Hacking/IT Incident             9
# Unauthorized Access/Disclosure, Other                           8
# Loss, Unauthorized Access/Disclosure                            5
# Theft, Other                                                    5
# Loss, Improper Disposal                                         3
# ...

# %%
#Question 6 CONT'
head = df['Type_of_Breach'].head(150)
plt.figure(figsize=(25,15))
sns.countplot(x = head)
# Out:
# <AxesSubplot:xlabel='Type_of_Breach', ylabel='count'>

# %%
#Question 7: What is the most common location of breached information?
common_breach_location = df['Location_of_Breached_Information'].value_counts()
common_breach_head = common_breach_location.head(1)
common_breach_head
# Out:
# Paper    227
# Name: Location_of_Breached_Information, dtype: int64

# %%
#Question 7 CONT'
plt.figure(figsize=(25,12))
sns.countplot(x = df['Location_of_Breached_Information'].tail(50))
# Out:
# <AxesSubplot:xlabel='Location_of_Breached_Information', ylabel='count'>

# %%
#Question 8: What state has the most affected individuals organized by year? (Attempted to organize by year, but jupyter notebook would not load.)
plt.figure(figsize = (20,10))
sns.barplot(x = df['State'], y = df['Individuals_Affected'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Individuals_Affected'>

# %%
#Question 9: Does the Breach type and location correlate to the number of individuals affected?
piv = df.pivot_table(values='Individuals_Affected',index='Type_of_Breach',columns='Location_of_Breached_Information')
piv.head(10)
# Out:
# Location_of_Breached_Information                   Desktop Computer  \
# Type_of_Breach
# Hacking/IT Incident                                        10921.25
# Hacking/IT Incident, Other                                      NaN
# Improper Disposal                                               NaN
# Improper Disposal, Unauthorized Access/Disclosure               NaN
# Loss                                                        6989.00
# Loss, Improper Disposal                                         NaN
# Loss, Other                                                     NaN
# Loss, Unauthorized Access/Disclosure                            NaN
# Loss, Unauthorized Access/Disclosure, Unknown                   NaN
# Loss, Unknown                                                   NaN
#
# Location_of_Breached_Information                   Desktop Computer, E-mail  \
# Type_of_Breach
# Hacking/IT Incident                                                     NaN
# ...

# %%
#Conclusion: There is no substantial correlation.
plt.figure(figsize = (10,5))
sns.heatmap(piv)
# Out:
# <AxesSubplot:xlabel='Location_of_Breached_Information', ylabel='Type_of_Breach'>

# %%
#Question 10: Does the year of the breach correlate to the type of breach that was performed? Was there a popular form of breach in a given year?
plt.figure(figsize = (25,10))
sns.countplot(x= df['Type_of_Breach'].head(165), data= df, hue= df['year'])
# Out:
# <AxesSubplot:xlabel='Type_of_Breach', ylabel='count'>

# %%
df
# Out:
#       Number                             Name_of_Covered_Entity State  \
# 0          0                         Brooke Army Medical Center    TX
# 1          1          Mid America Kidney Stone Association, LLC    MO
# 2          2    Alaska Department of Health and Social Services    AK
# 3          3  Health Services for Children with Special Need...    DC
# 4          4                           L. Douglas Carlson, M.D.    CA
# ...      ...                                                ...   ...
# 1050    1050                      Puerto Rico Health Insurance     PR
# 1051    1051                       Hospitalists of Brandon, LLC    FL
# 1052    1052                      Santa Rosa Memorial Hospital     CA
# 1053    1053         Group Health Plan of Hurley Medical Center    MI
# 1054    1054                            Abrham Tekola, M.D.,INC    CA
#
#       Individuals_Affected Date_of_Breach                  Type_of_Breach  \
# ...
